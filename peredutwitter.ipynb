# %%
import tweepy
import config

consumer_key = config.consumer_key
consumer_secret = config.consumer_secret
access_token = config.access_token
access_token_secret = config.access_token_secret

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

try:
    api.verify_credentials()
    print("Authentication OK")
except:
    print("Error during authentication")

user = api.me()
print(user.name)
print(user.location)
# Out:
# Authentication OK
# Peredution

# %%
# USER

user = api.get_user("MikezGarcia")

print("User details:")
print(user.name)
print(user.description)
print(user.location)

print("Last 20 Followers:")
for follower in user.followers():
    print(follower.name)
# Out:
# User details:
# Miguel Garcia
# Software Engineer at https://t.co/OKx1d849pt and Articles Author at @realpython
#
# MSc in Computer Science, I like working with open source techs and playing guitar.
# Argentina
# Last 20 Followers:
# B Bahmani
# Shabaz Ansari
# c
# Rey Joako
# NJ
# 🌸 CHesQ 🌸
# Salman Moosani
# The Golang Recruiter
# AdamWeissman
# WidePython
# Kyon Code
# Tobias Mesevage
# Konstantin
# Nick Thapen
# Czech A-Xii Da
# mahedi hasan
# Ryan Kauffman
# Kestrel Omnitech Inc.
# Gerzal Lazreg
# Kashif Iftikhar

# %%
# TRENDS

api.trends_available()
api.trends_place(1099805)
# Out:
# [{'trends': [{'name': '#BlackLivesMatter',
#     'url': 'http://twitter.com/search?q=%23BlackLivesMatter',
#     'promoted_content': None,
#     'query': '%23BlackLivesMatter',
#     'tweet_volume': 3334875},
#    {'name': '#LaunchAmerica',
#     'url': 'http://twitter.com/search?q=%23LaunchAmerica',
#     'promoted_content': None,
#     'query': '%23LaunchAmerica',
#     'tweet_volume': 328788},
#    {'name': '#NRW2020',
#     'url': 'http://twitter.com/search?q=%23NRW2020',
#     'promoted_content': None,
#     'query': '%23NRW2020',
#     'tweet_volume': None},
#    {'name': 'SANFL',
#     'url': 'http://twitter.com/search?q=SANFL',
#     'promoted_content': None,
#     'query': 'SANFL',
#     'tweet_volume': None},
#    {'name': '#Trump',
#     'url': 'http://twitter.com/search?q=%23Trump',
#     'promoted_content': None,
#     'query': '%23Trump',
#     'tweet_volume': 64856},
#    {'name': 'Adelaide Oval',
#     'url': 'http://twitter.com/search?q=%22Adelaide+Oval%22',
#     'promoted_content': None,
#     'query': '%22Adelaide+Oval%22',
#     'tweet_volume': None},
#    {'name': '#NRLBroncosEels',
#     'url': 'http://twitter.com/search?q=%23NRLBroncosEels',
#     'promoted_content': None,
#     'query': '%23NRLBroncosEels',
#     'tweet_volume': None},
#    {'name': 'WACA',
#     'url': 'http://twitter.com/search?q=WACA',
#     'promoted_content': None,
#     'query': 'WACA',
#     'tweet_volume': None},
#    {'name': 'madison',
#     'url': 'http://twitter.com/search?q=madison',
#     'promoted_content': None,
#     'query': 'madison',
#     'tweet_volume': 36519},
#    {'name': 'Monash Freeway',
#     'url': 'http://twitter.com/search?q=%22Monash+Freeway%22',
#     'promoted_content': None,
#     'query': '%22Monash+Freeway%22',
#     'tweet_volume': None},
#    {'name': 'Public Education Day',
#     'url': 'http://twitter.com/search?q=%22Public+Education+Day%22',
#     'promoted_content': None,
#     'query': '%22Public+Education+Day%22',
#     'tweet_volume': None},
#    {'name': 'News Corp',
#     'url': 'http://twitter.com/search?q=%22News+Corp%22',
#     'promoted_content': None,
#     'query': '%22News+Corp%22',
#     'tweet_volume': None},
#    {'name': 'Rio Tinto',
#     'url': 'http://twitter.com/search?q=%22Rio+Tinto%22',
#     'promoted_content': None,
#     'query': '%22Rio+Tinto%22',
#     'tweet_volume': None},
#    {'name': 'Aboriginal',
#     'url': 'http://twitter.com/search?q=Aboriginal',
#     'promoted_content': None,
#     'query': 'Aboriginal',
#     'tweet_volume': 11098},
#    {'name': 'Larry Kramer',
#     'url': 'http://twitter.com/search?q=%22Larry+Kramer%22',
#     'promoted_content': None,
#     'query': '%22Larry+Kramer%22',
#     'tweet_volume': 81864},
#    {'name': 'Indigenous',
#     'url': 'http://twitter.com/search?q=Indigenous',
#     'promoted_content': None,
#     'query': 'Indigenous',
#     'tweet_volume': 34709},
#    {'name': 'Blackwater',
#     'url': 'http://twitter.com/search?q=Blackwater',
#     'promoted_content': None,
#     'query': 'Blackwater',
#     'tweet_volume': None},
#    {'name': 'Torres Strait',
#     'url': 'http://twitter.com/search?q=%22Torres+Strait%22',
#     'promoted_content': None,
#     'query': '%22Torres+Strait%22',
#     'tweet_volume': None},
#    {'name': 'Karen',
#     'url': 'http://twitter.com/search?q=Karen',
#     'promoted_content': None,
#     'query': 'Karen',
#     'tweet_volume': 218880},
#    {'name': 'ASADA',
#     'url': 'http://twitter.com/search?q=ASADA',
#     'promoted_content': None,
#     'query': 'ASADA',
#     'tweet_volume': None},
#    {'name': 'Traditional Owners',
#     'url': 'http://twitter.com/search?q=%22Traditional+Owners%22',
#     'promoted_content': None,
#     'query': '%22Traditional+Owners%22',
#     'tweet_volume': None},
#    {'name': 'John Boyega',
#     'url': 'http://twitter.com/search?q=%22John+Boyega%22',
#     'promoted_content': None,
#     'query': '%22John+Boyega%22',
#     'tweet_volume': 268926},
#    {'name': 'Minnesota',
#     'url': 'http://twitter.com/search?q=Minnesota',
#     'promoted_content': None,
#     'query': 'Minnesota',
#     'tweet_volume': 256609},
#    {'name': 'Hong Kong',
#     'url': 'http://twitter.com/search?q=%22Hong+Kong%22',
#     'promoted_content': None,
#     'query': '%22Hong+Kong%22',
#     'tweet_volume': 602243},
#    {'name': 'Swans',
#     'url': 'http://twitter.com/search?q=Swans',
#     'promoted_content': None,
#     'query': 'Swans',
#     'tweet_volume': None},
#    {'name': 'Murdoch',
#     'url': 'http://twitter.com/search?q=Murdoch',
#     'promoted_content': None,
#     'query': 'Murdoch',
#     'tweet_volume': None},
#    {'name': '#NewsCorp',
#     'url': 'http://twitter.com/search?q=%23NewsCorp',
#     'promoted_content': None,
#     'query': '%23NewsCorp',
#     'tweet_volume': None},
#    {'name': '#impact2020online',
#     'url': 'http://twitter.com/search?q=%23impact2020online',
#     'promoted_content': None,
#     'query': '%23impact2020online',
#     'tweet_volume': None},
#    {'name': '#ohbrookeohtaylorohbrooke',
#     'url': 'http://twitter.com/search?q=%23ohbrookeohtaylorohbrooke',
#     'promoted_content': None,
#     'query': '%23ohbrookeohtaylorohbrooke',
#     'tweet_volume': None},
#    {'name': '#imhereforyou',
#     'url': 'http://twitter.com/search?q=%23imhereforyou',
#     'promoted_content': None,
#     'query': '%23imhereforyou',
#     'tweet_volume': None},
#    {'name': '#bronxnation',
#     'url': 'http://twitter.com/search?q=%23bronxnation',
#     'promoted_content': None,
#     'query': '%23bronxnation',
#     'tweet_volume': None},
#    {'name': '#LoveYourWork',
#     'url': 'http://twitter.com/search?q=%23LoveYourWork',
#     'promoted_content': None,
#     'query': '%23LoveYourWork',
#     'tweet_volume': None},
#    {'name': '#BCM325',
#     'url': 'http://twitter.com/search?q=%23BCM325',
#     'promoted_content': None,
#     'query': '%23BCM325',
#     'tweet_volume': None},
#    {'name': '#AlitaBattleAngel',
#     'url': 'http://twitter.com/search?q=%23AlitaBattleAngel',
#     'promoted_content': None,
#     'query': '%23AlitaBattleAngel',
#     'tweet_volume': None},
#    {'name': '#SpaceX',
#     'url': 'http://twitter.com/search?q=%23SpaceX',
#     'promoted_content': None,
#     'query': '%23SpaceX',
#     'tweet_volume': 166080},
#    {'name': '#HerNameIsWillow',
#     'url': 'http://twitter.com/search?q=%23HerNameIsWillow',
#     'promoted_content': None,
#     'query': '%23HerNameIsWillow',
#     'tweet_volume': None},
#    {'name': '#ReconciliationWeek',
#     'url': 'http://twitter.com/search?q=%23ReconciliationWeek',
#     'promoted_content': None,
#     'query': '%23ReconciliationWeek',
#     'tweet_volume': None},
#    {'name': '#Chromatica',
#     'url': 'http://twitter.com/search?q=%23Chromatica',
#     'promoted_content': None,
#     'query': '%23Chromatica',
#     'tweet_volume': 240889},
#    {'name': '#AEWDynamite',
#     'url': 'http://twitter.com/search?q=%23AEWDynamite',
#     'promoted_content': None,
#     'query': '%23AEWDynamite',
#     'tweet_volume': 61991},
#    {'name': '#FactCheck',
#     'url': 'http://twitter.com/search?q=%23FactCheck',
#     'promoted_content': None,
#     'query': '%23FactCheck',
#     'tweet_volume': 31489},
#    {'name': '#MasterChefAU',
#     'url': 'http://twitter.com/search?q=%23MasterChefAU',
#     'promoted_content': None,
#     'query': '%23MasterChefAU',
#     'tweet_volume': None},
#    {'name': '#JusticeForFloyd',
#     'url': 'http://twitter.com/search?q=%23JusticeForFloyd',
#     'promoted_content': None,
#     'query': '%23JusticeForFloyd',
#     'tweet_volume': 123022},
#    {'name': '#wwenxt',
#     'url': 'http://twitter.com/search?q=%23wwenxt',
#     'promoted_content': None,
#     'query': '%23wwenxt',
#     'tweet_volume': 31856},
#    {'name': '#thesecretsshekeeps',
#     'url': 'http://twitter.com/search?q=%23thesecretsshekeeps',
#     'promoted_content': None,
#     'query': '%23thesecretsshekeeps',
#     'tweet_volume': None},
#    {'name': '#requestival',
#     'url': 'http://twitter.com/search?q=%23requestival',
#     'promoted_content': None,
#     'query': '%23requestival',
#     'tweet_volume': None},
#    {'name': '#CreateSkills',
#     'url': 'http://twitter.com/search?q=%23CreateSkills',
#     'promoted_content': None,
#     'query': '%23CreateSkills',
#     'tweet_volume': None},
#    {'name': '#wednesdaywordexpo',
#     'url': 'http://twitter.com/search?q=%23wednesdaywordexpo',
#     'promoted_content': None,
#     'query': '%23wednesdaywordexpo',
#     'tweet_volume': 38133},
#    {'name': '#JusticeForCarolyn',
#     'url': 'http://twitter.com/search?q=%23JusticeForCarolyn',
#     'promoted_content': None,
#     'query': '%23JusticeForCarolyn',
#     'tweet_volume': 60988},
#    {'name': '#scottyfrommarketing',
#     'url': 'http://twitter.com/search?q=%23scottyfrommarketing',
#     'promoted_content': None,
#     'query': '%23scottyfrommarketing',
#     'tweet_volume': None},
#    {'name': '#biggestmorningtea',
#     'url': 'http://twitter.com/search?q=%23biggestmorningtea',
#     'promoted_content': None,
#     'query': '%23biggestmorningtea',
#     'tweet_volume': None}],
#   'as_of': '2020-05-28T07:52:47Z',
#   'created_at': '2020-05-28T07:48:44Z',
#   'locations': [{'name': 'Adelaide', 'woeid': 1099805}]}]

# %%
# SEARCH

search = 'cybersecurity'
numberOfTweets = 5

# %%
# STANDARD

api = tweepy.API(auth)
for tweet in tweepy.Cursor(api.search, q=search, tweet_mode='extended', include_entities=True).items(numberOfTweets):
    print(f'{tweet.full_text}\n\n===\n\n')
    print(tweet)
# Out:
# RT @eRakshaofficial: Gear up! #eRaksha competitions 2020 is coming soon... Stay tuned.
#
# #CyberPeace #CyberSecurity https://t.co/dkX3BRXkEH
#
# ===
#
#
# Status(_api=<tweepy.api.API object at 0x000002365F6BF250>, _json={'created_at': 'Thu May 28 11:45:14 +0000 2020', 'id': 1265972397816967169, 'id_str': '1265972397816967169', 'full_text': 'RT @eRakshaofficial: Gear up! #eRaksha competitions 2020 is coming soon... Stay tuned.\n\n#CyberPeace #CyberSecurity https://t.co/dkX3BRXkEH', 'truncated': False, 'display_text_range': [0, 138], 'entities': {'hashtags': [{'text': 'eRaksha', 'indices': [30, 38]}, {'text': 'CyberPeace', 'indices': [88, 99]}, {'text': 'CyberSecurity', 'indices': [100, 114]}], 'symbols': [], 'user_mentions': [{'screen_name': 'eRakshaofficial', 'name': 'eRaksha', 'id': 1118083287744860160, 'id_str': '1118083287744860160', 'indices': [3, 19]}], 'urls': [], 'media': [{'id': 1265927431761866752, 'id_str': '1265927431761866752', 'indices': [115, 138], 'media_url': 'http://pbs.twimg.com/media/EZF6SsGWsAA14WF.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EZF6SsGWsAA14WF.jpg', 'url': 'https://t.co/dkX3BRXkEH', 'display_url': 'pic.twitter.com/dkX3BRXkEH', 'expanded_url': 'https://twitter.com/eRakshaofficial/status/1265928075801505792/photo/1', 'type': 'photo', 'sizes': {'medium': {'w': 1200, 'h': 900, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 1280, 'h': 960, 'resize': 'fit'}, 'small': {'w': 680, 'h': 510, 'resize': 'fit'}}, 'source_status_id': 1265928075801505792, 'source_status_id_str': '1265928075801505792', 'source_user_id': 1118083287744860160, 'source_user_id_str': '1118083287744860160'}]}, 'extended_entities': {'media': [{'id': 1265927431761866752, 'id_str': '1265927431761866752', 'indices': [115, 138], 'media_url': 'http://pbs.twimg.com/media/EZF6SsGWsAA14WF.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EZF6SsGWsAA14WF.jpg', 'url': 'https://t.co/dkX3BRXkEH', 'display_url': 'pic.twitter.com/dkX3BRXkEH', 'expanded_url': 'https://twitter.com/eRakshaofficial/status/1265928075801505792/photo/1', 'type': 'photo', 'sizes': {'medium': {'w': 1200, 'h': 900, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 1280, 'h': 960, 'resize': 'fit'}, 'small': {'w': 680, 'h': 510, 'resize': 'fit'}}, 'source_status_id': 1265928075801505792, 'source_status_id_str': '1265928075801505792', 'source_user_id': 1118083287744860160, 'source_user_id_str': '1118083287744860160'}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 16307816, 'id_str': '16307816', 'name': 'ѕαtчα prαdhαnसत्य नारायण प्रधान ସତ୍ଯପ୍ରଧାନ-DG NDRF', 'screen_name': 'satyaprad1', 'location': 'New Delhi, India', 'description': 'IPS,DG National Disaster Response Force, Chevening Scholar,Prez Medal, Queen’sAward4policing, ❤️my🇮🇳, RT≠endorsement https://t.co/21uxuyT95k', 'url': None, 'entities': {'description': {'urls': [{'url': 'https://t.co/21uxuyT95k', 'expanded_url': 'http://instagram.com/satyaprad1', 'display_url': 'instagram.com/satyaprad1', 'indices': [117, 140]}]}}, 'protected': False, 'followers_count': 7009, 'friends_count': 1253, 'listed_count': 12, 'created_at': 'Tue Sep 16 06:39:45 +0000 2008', 'favourites_count': 299, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 3140, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1251729114911760385/zLQFo_mx_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1251729114911760385/zLQF ...
# Artificial intelligence doesn't require burdensome regulation. » https://t.co/StukrvraUt
#
#  #AI #MachineLearning #ML #BigData #IoT #DeepLearning #Robotics
#
# ===
#
#
# Status(_api=<tweepy.api.API object at 0x000002365F6BF250>, _json={'created_at': 'Thu May 28 11:45:09 +0000 2020', 'id': 1265972375054692352, 'id_str': '1265972375054692352', 'full_text': "Artificial intelligence doesn't require burdensome regulation. » https://t.co/StukrvraUt\n \n #AI #MachineLearning #ML #BigData #IoT #DeepLearning #Robotics", 'truncated': False, 'display_text_range': [0, 154], 'entities': {'hashtags': [{'text': 'AI', 'indices': [92, 95]}, {'text': 'MachineLearning', 'indices': [96, 112]}, {'text': 'ML', 'indices': [113, 116]}, {'text': 'BigData', 'indices': [117, 125]}, {'text': 'IoT', 'indices': [126, 130]}, {'text': 'DeepLearning', 'indices': [131, 144]}, {'text': 'Robotics', 'indices': [145, 154]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/StukrvraUt', 'expanded_url': 'http://ow.ly/s8yI30qKapR', 'display_url': 'ow.ly/s8yI30qKapR', 'indices': [65, 88]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 54317231, 'id_str': '54317231', 'name': 'Arjen van Berkum', 'screen_name': 'arjenvanberkum', 'location': 'Delft NL', 'description': 'Future of #work| Columnist & speaker | Motivator | lives #Automation and #AI | Delft | #Innovation | #disruption | #CDO | #RPA | #contractmanagement', 'url': 'https://t.co/I07nsCRfZA', 'entities': {'url': {'urls': [{'url': 'https://t.co/I07nsCRfZA', 'expanded_url': 'http://www.arjenvanberkum.nl', 'display_url': 'arjenvanberkum.nl', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 35102, 'friends_count': 26230, 'listed_count': 2773, 'created_at': 'Mon Jul 06 20:10:41 +0000 2009', 'favourites_count': 7235, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 55236, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/627125933800075264/gtLxqzzN_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/627125933800075264/gtLxqzzN_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/54317231/1579452525', 'profile_link_color': 'EB1818', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, created_at=datetime.datetime(2020, 5, 28, 11, 45, 9), id=1265972375054692352, id_str='1265972375054692352', full_text="Artificial intelligence doesn't require burdensome regulation. » https://t.co/StukrvraUt\n \n #AI #MachineLearning #ML #BigData #IoT #DeepLearning #Robotics", truncated=False, display_text_range=[0, 154], entities={'hashtags': [{'text': 'AI', 'indices': [92, 95]}, {'text': 'MachineLearning', 'indices': [96, 112]}, {'text': 'ML', 'indices': [113, 116]}, {'text': 'BigData', 'indices': [117, 125]}, {'text': 'IoT', 'indices': [126, 130]}, {'text': 'DeepLearning', 'indices': [131, 144]}, {'text': 'Robotics', 'indices': [145, 154]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/StukrvraUt', 'e ...
# What steps are you taking towards protecting your business during the COVID-19 pandemic?
#
# Out of 345 individuals surveyed, more than 60% had reported COVID-19 related attacks. Read more here: https://t.co/QsRnLIXINf
#
# #cybersecurity #covid-19 #coronavirus
#
# ===
#
#
# Status(_api=<tweepy.api.API object at 0x000002365F6BF250>, _json={'created_at': 'Thu May 28 11:45:05 +0000 2020', 'id': 1265972358348713984, 'id_str': '1265972358348713984', 'full_text': 'What steps are you taking towards protecting your business during the COVID-19 pandemic?\n\nOut of 345 individuals surveyed, more than 60% had reported COVID-19 related attacks. Read more here: https://t.co/QsRnLIXINf\n\n#cybersecurity #covid-19 #coronavirus', 'truncated': False, 'display_text_range': [0, 254], 'entities': {'hashtags': [{'text': 'cybersecurity', 'indices': [217, 231]}, {'text': 'covid', 'indices': [232, 238]}, {'text': 'coronavirus', 'indices': [242, 254]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/QsRnLIXINf', 'expanded_url': 'http://ow.ly/A04a50zScHT', 'display_url': 'ow.ly/A04a50zScHT', 'indices': [192, 215]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 105282737, 'id_str': '105282737', 'name': 'IntaForensics', 'screen_name': 'IntaForensics', 'location': 'Warwickshire, UK', 'description': 'Providers of #DigitalForensics, #CyberSecurity, @LimaForensics software, training, expert witness and data recovery for police, commercial & legal sectors', 'url': 'https://t.co/MJ6Ymqb8k9', 'entities': {'url': {'urls': [{'url': 'https://t.co/MJ6Ymqb8k9', 'expanded_url': 'https://www.intaforensics.com', 'display_url': 'intaforensics.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 1091, 'friends_count': 514, 'listed_count': 44, 'created_at': 'Fri Jan 15 22:51:31 +0000 2010', 'favourites_count': 364, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 2774, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '0E045F', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/824642207806291969/fzwRxsTj_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/824642207806291969/fzwRxsTj_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/105282737/1582043077', 'profile_link_color': '0E045F', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, created_at=datetime.datetime(2020, 5, 28, 11, 45, 5), id=1265972358348713984, id_str='1265972358348713984', full_text='What steps are you taking towards protecting your business during the COVID-19 pandemic?\n\nOut of 345 individuals surveyed, more than 60% had reported COVID-19 related attacks. Read more here: https://t.co/QsRnLIXINf\n\n#cybersecurity #covid-19 #coronavirus', truncated=False, display_text_range=[0, 254], entities={'hashtags': [{'text': 'cybersecurity', 'indices': [217, 231]}, {'text': 'covid', 'indices': [232, 238]}, {'text': 'coronavirus', 'indices': [242, 254]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/QsRnLIXINf', 'expanded_url': 'http://ow.ly/A04a50zScHT', 'display_url': 'ow.ly/A04a50zScHT', 'indices': [192, 215]}]}, metadata={'iso ...
# #Identity Silos &gt; Shining a light on the problem of shadow identities &gt; https://t.co/Kb3NafAWOf via @TechNative
#
# #tech #IAM #security #cybersecurity #infosec #CISO #CIO #CTO #leadership #management #leaders https://t.co/tuHxdCPLC7
#
# ===
#
#
# Status(_api=<tweepy.api.API object at 0x000002365F6BF250>, _json={'created_at': 'Thu May 28 11:45:04 +0000 2020', 'id': 1265972355165310976, 'id_str': '1265972355165310976', 'full_text': '#Identity Silos &gt; Shining a light on the problem of shadow identities &gt; https://t.co/Kb3NafAWOf via @TechNative \n\n#tech #IAM #security #cybersecurity #infosec #CISO #CIO #CTO #leadership #management #leaders https://t.co/tuHxdCPLC7', 'truncated': False, 'display_text_range': [0, 213], 'entities': {'hashtags': [{'text': 'Identity', 'indices': [0, 9]}, {'text': 'tech', 'indices': [120, 125]}, {'text': 'IAM', 'indices': [126, 130]}, {'text': 'security', 'indices': [131, 140]}, {'text': 'cybersecurity', 'indices': [141, 155]}, {'text': 'infosec', 'indices': [156, 164]}, {'text': 'CISO', 'indices': [165, 170]}, {'text': 'CIO', 'indices': [171, 175]}, {'text': 'CTO', 'indices': [176, 180]}, {'text': 'leadership', 'indices': [181, 192]}, {'text': 'management', 'indices': [193, 204]}, {'text': 'leaders', 'indices': [205, 213]}], 'symbols': [], 'user_mentions': [{'screen_name': 'TechNative', 'name': 'TechNative', 'id': 3937914677, 'id_str': '3937914677', 'indices': [106, 117]}], 'urls': [{'url': 'https://t.co/Kb3NafAWOf', 'expanded_url': 'https://buff.ly/2zkwQrf', 'display_url': 'buff.ly/2zkwQrf', 'indices': [78, 101]}], 'media': [{'id': 1265972353202348034, 'id_str': '1265972353202348034', 'indices': [214, 237], 'media_url': 'http://pbs.twimg.com/media/EZGjJdgXYAIxjsz.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EZGjJdgXYAIxjsz.jpg', 'url': 'https://t.co/tuHxdCPLC7', 'display_url': 'pic.twitter.com/tuHxdCPLC7', 'expanded_url': 'https://twitter.com/Corix_JC/status/1265972355165310976/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 1700, 'h': 1135, 'resize': 'fit'}, 'medium': {'w': 1200, 'h': 801, 'resize': 'fit'}, 'small': {'w': 680, 'h': 454, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1265972353202348034, 'id_str': '1265972353202348034', 'indices': [214, 237], 'media_url': 'http://pbs.twimg.com/media/EZGjJdgXYAIxjsz.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EZGjJdgXYAIxjsz.jpg', 'url': 'https://t.co/tuHxdCPLC7', 'display_url': 'pic.twitter.com/tuHxdCPLC7', 'expanded_url': 'https://twitter.com/Corix_JC/status/1265972355165310976/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 1700, 'h': 1135, 'resize': 'fit'}, 'medium': {'w': 1200, 'h': 801, 'resize': 'fit'}, 'small': {'w': 680, 'h': 454, 'resize': 'fit'}}}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 3345194367, 'id_str': '3345194367', 'name': 'JC Gaillard', 'screen_name': 'Corix_JC', 'location': 'London, England', 'description': 'Founder & MD @CorixPartners | Co-president #CyberSecurity Group @TelecomParisAl | Non Executive Director | Board Advisor | Author | Cyber Security Leader', 'url': 'https://t.co/Or8OPJ8Ulx', 'entities': {'url': {'urls': [{'url': 'https://t.co/Or8OPJ8Ulx', 'expanded_url': 'https://corixpartners.com/', 'display_url': 'corixpartners.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 5886, 'friends_count': 5299, 'listed_count': 1876, 'created_at': 'Thu Jun 25 08:13:57 +0000 2015', 'favourites_count': 51750, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 54849, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',  ...
# RT @crossbowlabs: Can you get this question right? If Yes well You already are a Winner. Go On Drop your Answer in the Comment Section and…
#
# ===
#
#
# Status(_api=<tweepy.api.API object at 0x000002365F6BF250>, _json={'created_at': 'Thu May 28 11:44:51 +0000 2020', 'id': 1265972301415305219, 'id_str': '1265972301415305219', 'full_text': 'RT @crossbowlabs: Can you get this question right? If Yes well You already are a Winner. Go On Drop your Answer in the Comment Section and…', 'truncated': False, 'display_text_range': [0, 139], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'crossbowlabs', 'name': 'Crossbow Labs', 'id': 2864378988, 'id_str': '2864378988', 'indices': [3, 16]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1077618768136658944, 'id_str': '1077618768136658944', 'name': 'Prashant Awasthi', 'screen_name': 'prashant778866', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 186, 'friends_count': 743, 'listed_count': 0, 'created_at': 'Tue Dec 25 17:35:10 +0000 2018', 'favourites_count': 6662, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 11047, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1187066477687406592/zDyAbDfo_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1187066477687406592/zDyAbDfo_normal.jpg', 'profile_link_color': '981CEB', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Fri May 22 14:37:04 +0000 2020', 'id': 1263841310911287296, 'id_str': '1263841310911287296', 'full_text': 'Can you get this question right? If Yes well You already are a Winner. Go On Drop your Answer in the Comment Section and Celebrate 🙌 .  #CyberQuiz #CyberSecurity #CyberProtection #DataProtection #EthicalHacker #Malware #Phishing #CyberFraud #EthicalHacking #DataProtection https://t.co/LbDh9mGJ20', 'truncated': False, 'display_text_range': [0, 272], 'entities': {'hashtags': [{'text': 'CyberQuiz', 'indices': [136, 146]}, {'text': 'CyberSecurity', 'indices': [147, 161]}, {'text': 'CyberProtection', 'indices': [162, 178]}, {'text': 'DataProtection', 'indices': [179, 194]}, {'text': 'EthicalHacker', 'indices': [195, 209]}, {'text': 'Malware', 'indices': [210, 218]}, {'text': 'Phishing', 'indices': [219, 228]}, {'text': 'CyberFraud', 'indices': [229, 240]}, {'text': 'EthicalHacking', 'indices': [241, 256]}, {'text': 'DataProtection', 'indices': [257, 272]}], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 1263841308201766913, 'id_str': '1263841308201766913', 'indices': [273, 296], 'media_url': 'http://pbs.twimg.com/media/EYoQ-UPU0AEy5Fc.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EYoQ-UPU0AEy5Fc.jpg', 'url': 'https://t.co/LbDh9mGJ20', 'display_url': 'pic.twitter.com/LbDh9mGJ20', 'expanded_url': 'https://twitter.com/crossbowlabs/status/1263841310911287296/photo/1', 'type': 'photo', 'sizes': {'medium': {'w': 1200, 'h': 673, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 2048, 'h': 1149, 're ...

# %%
# AS PANDAS DATAFRAME

import pandas as pd
api = tweepy.API(auth)
results = api.search(q=search, count=numberOfTweets)
json_data = [r._json for r in results]
df = pd.json_normalize(json_data)
df
# Out:
#                        created_at                   id               id_str  \
# 0  Thu May 28 08:05:37 +0000 2020  1265917129754198017  1265917129754198017
# 1  Thu May 28 08:05:33 +0000 2020  1265917111261630465  1265917111261630465
# 2  Thu May 28 08:05:22 +0000 2020  1265917065929592832  1265917065929592832
# 3  Thu May 28 08:05:15 +0000 2020  1265917034698665984  1265917034698665984
# 4  Thu May 28 08:05:13 +0000 2020  1265917028818472960  1265917028818472960
#
#                                                 text  truncated  \
# 0  New Android Flaw Affecting Over 1 Billion Phon...       True
# 1  RT @enricomolinari: A easly flood-wall can sav...      False
# 2  Interesting study on #authentication and #acce...       True
# 3  @Akamai blocked a large #PPS-focused attack in...       True
# 4  State-of-the-art #IP &amp; #IT-based solutions...       True
#
#                                               source in_reply_to_status_id  \
# 0  <a href="https://mobile.twitter.com" rel="nofo...                  None
# 1  <a href="http://twitter.com/download/android" ...                  None
# 2  <a href="http://www.linkedin.com/" rel="nofoll...                  None
# 3  <a href="http://dynamicsignal.com/" rel="nofol...                  None
# 4  <a href="https://mobile.twitter.com" rel="nofo...                  None
#
#   in_reply_to_status_id_str  in_reply_to_user_id in_reply_to_user_id_str  ...  \
# 0                      None                  NaN                    None  ...
# 1                      None                  NaN                    None  ...
# 2                      None                  NaN                    None  ...
# 3                      None           19622847.0                19622847  ...
# 4                      None                  NaN                    None  ...
#
#   retweeted_status.coordinates retweeted_status.place  \
# 0                          NaN                    NaN
# 1                          NaN                    NaN
# 2                          NaN                    NaN
# 3                          NaN                    NaN
# 4                          NaN                    NaN
#
#   retweeted_status.contributors retweeted_status.is_quote_status  \
# 0                           NaN                              NaN
# 1                           NaN                            False
# 2                           NaN                              NaN
# 3                           NaN                              NaN
# 4                           NaN                              NaN
#
#   retweeted_status.retweet_count  retweeted_status.favorite_count  \
# 0                            NaN                              NaN
# 1                           11.0                             17.0
# 2                            NaN                              NaN
# 3                            NaN                              NaN
# 4                            NaN                              NaN
#
#    retweeted_status.favorited  retweeted_status.retweeted  \
# 0                         NaN                         NaN
# 1                       False                       False
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#    retweeted_status.possibly_sensitive  retweeted_status.lang
# 0                                  NaN                    NaN
# 1                                False                     en
# 2                                  NaN                    NaN
# 3                                  NaN                    NaN
# 4                                  NaN                    NaN
#
# [5 rows x 142 columns]

# %%
# AS JSON

api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())
results = api.search(q=search, count=numberOfTweets)
results.keys()
results["statuses"]
# Out:
# [{'created_at': 'Thu May 28 08:05:37 +0000 2020',
#   'id': 1265917129754198017,
#   'id_str': '1265917129754198017',
#   'text': 'New Android Flaw Affecting Over 1 Billion Phones Let Attackers Hijack Apps.\nhttps://t.co/SRQUi32lQ9\n#phishing… https://t.co/5O6pX8S2hH',
#   'truncated': True,
#   'entities': {'hashtags': [{'text': 'phishing', 'indices': [100, 109]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/SRQUi32lQ9',
#      'expanded_url': 'https://thehackernews.com/2020/05/stranhogg-android-vulnerability.html',
#      'display_url': 'thehackernews.com/2020/05/stranh…',
#      'indices': [76, 99]},
#     {'url': 'https://t.co/5O6pX8S2hH',
#      'expanded_url': 'https://twitter.com/i/web/status/1265917129754198017',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [111, 134]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1214894058780286976,
#    'id_str': '1214894058780286976',
#    'name': 'INFiLX',
#    'screen_name': 'INFiLXTweets',
#    'location': 'Dubai, UAE',
#    'description': 'We at INFiLX offers services in #CyberSecurity such as Mobile App Security Testing, Web Application Security Testing, Network VAPT, Cloud Security Assessment.',
#    'url': 'https://t.co/0XzDTp0GwY',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/0XzDTp0GwY',
#        'expanded_url': 'https://infilx.com/',
#        'display_url': 'infilx.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 13,
#    'friends_count': 83,
#    'listed_count': 0,
#    'created_at': 'Wed Jan 08 12:59:06 +0000 2020',
#    'favourites_count': 27,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 66,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1254986140278329344/ayHJwN4n_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1254986140278329344/ayHJwN4n_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1214894058780286976/1579269763',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Thu May 28 08:05:33 +0000 2020',
#   'id': 1265917111261630465,
#   'id_str': '1265917111261630465',
#   'text': 'RT @enricomolinari: A easly flood-wall can save property from being damaged by flash floods! TY @Bluemont @enricomolinari #smartcities #ehe…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'smartcities', 'indices': [122, 134]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'enricomolinari',
#      'name': '🔛 Enrico Molinari #FinTech #MarTech 🇮🇹🇪🇺🇺🇸',
#      'id': 75673231,
#      'id_str': '75673231',
#      'indices': [3, 18]},
#     {'screen_name': 'Bluemont',
#      'name': 'Bluemont Technology',
#      'id': 27707647,
#      'id_str': '27707647',
#      'indices': [96, 105]},
#     {'screen_name': 'enricomolinari',
#      'name': '🔛 Enrico Molinari #FinTech #MarTech 🇮🇹🇪🇺🇺🇸',
#      'id': 75673231,
#      'id_str': '75673231',
#      'indices': [106, 121]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1220683730148347912,
#    'id_str': '1220683730148347912',
#    'name': 'Theo',
#    'screen_name': 'Theo81317148',
#    'location': 'Earth',
#    'description': 'Futurism, IoT, IoMT, ML, DL, BD, Tech, TSLA, Quantum #BTC #bitcoin #link #ethereum #blockchain, Soccer, F1.\nThe Netherlands, Brabant, Oss. PVDA🌹',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 338,
#    'friends_count': 914,
#    'listed_count': 5,
#    'created_at': 'Fri Jan 24 12:24:44 +0000 2020',
#    'favourites_count': 2262,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 4317,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1222849050585845760/zXdeYgL8_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1222849050585845760/zXdeYgL8_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1220683730148347912/1580384960',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Thu May 28 03:37:00 +0000 2020',
#    'id': 1265849527027859457,
#    'id_str': '1265849527027859457',
#    'text': 'A easly flood-wall can save property from being damaged by flash floods! TY @Bluemont @enricomolinari #smartcities… https://t.co/Z7GP2DRbUE',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'smartcities', 'indices': [102, 114]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Bluemont',
#       'name': 'Bluemont Technology',
#       'id': 27707647,
#       'id_str': '27707647',
#       'indices': [76, 85]},
#      {'screen_name': 'enricomolinari',
#       'name': '🔛 Enrico Molinari #FinTech #MarTech 🇮🇹🇪🇺🇺🇸',
#       'id': 75673231,
#       'id_str': '75673231',
#       'indices': [86, 101]}],
#     'urls': [{'url': 'https://t.co/Z7GP2DRbUE',
#       'expanded_url': 'https://twitter.com/i/web/status/1265849527027859457',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 75673231,
#     'id_str': '75673231',
#     'name': '🔛 Enrico Molinari #FinTech #MarTech 🇮🇹🇪🇺🇺🇸',
#     'screen_name': 'enricomolinari',
#     'location': '🇮🇹 🇪🇺 🇺🇸    ',
#     'description': 'innovation manager & #CMO leader ⭐ university #martech #fintech #innovation professor ⭐ speaker ⭐ spokesperson President @ConfAssTW ⭐ 1° 🌎 #FinTech influencer',
#     'url': 'https://t.co/g0d0tlfxUb',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/g0d0tlfxUb',
#         'expanded_url': 'https://www.linkedin.com/in/enrico-molinari/',
#         'display_url': 'linkedin.com/in/enrico-moli…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 24471,
#     'friends_count': 5804,
#     'listed_count': 282,
#     'created_at': 'Sat Sep 19 23:55:41 +0000 2009',
#     'favourites_count': 43253,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 36840,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1089894324001742848/rBFMek1N_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1089894324001742848/rBFMek1N_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/75673231/1548686447',
#     'profile_link_color': '000088',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 11,
#    'favorite_count': 17,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 11,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Thu May 28 08:05:22 +0000 2020',
#   'id': 1265917065929592832,
#   'id_str': '1265917065929592832',
#   'text': 'Interesting study on #authentication and #access control of Internet-of-Things (#IoT) devices show that 16 of 19 po… https://t.co/3wxg04WVGJ',
#   'truncated': True,
#   'entities': {'hashtags': [{'text': 'authentication', 'indices': [21, 36]},
#     {'text': 'access', 'indices': [41, 48]},
#     {'text': 'IoT', 'indices': [80, 84]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/3wxg04WVGJ',
#      'expanded_url': 'https://twitter.com/i/web/status/1265917065929592832',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://www.linkedin.com/" rel="nofollow">LinkedIn</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 374932904,
#    'id_str': '374932904',
#    'name': 'Mario Procopio',
#    'screen_name': 'The_Proc',
#    'location': 'Amsterdam, North Holland',
#    'description': 'Global CISO at Veon - mainly sharing my routine OSINT cyber threat review',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 248,
#    'friends_count': 373,
#    'listed_count': 57,
#    'created_at': 'Sat Sep 17 06:35:54 +0000 2011',
#    'favourites_count': 1093,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 7063,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1248298869923840001/KiadLAX2_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1248298869923840001/KiadLAX2_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/374932904/1452940416',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Thu May 28 08:05:15 +0000 2020',
#   'id': 1265917034698665984,
#   'id_str': '1265917034698665984',
#   'text': '@Akamai blocked a large #PPS-focused attack in a record-setting zero seconds, utilizing a proactive mitigation post… https://t.co/vPoxNXKB7L',
#   'truncated': True,
#   'entities': {'hashtags': [{'text': 'PPS', 'indices': [24, 28]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'Akamai',
#      'name': 'Akamai Technologies',
#      'id': 19622847,
#      'id_str': '19622847',
#      'indices': [0, 7]}],
#    'urls': [{'url': 'https://t.co/vPoxNXKB7L',
#      'expanded_url': 'https://twitter.com/i/web/status/1265917034698665984',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://dynamicsignal.com/" rel="nofollow">Dynamic Signal</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': 19622847,
#   'in_reply_to_user_id_str': '19622847',
#   'in_reply_to_screen_name': 'Akamai',
#   'user': {'id': 44858298,
#    'id_str': '44858298',
#    'name': 'Karine GourdonKeller',
#    'screen_name': 'karinekell',
#    'location': 'Munich',
#    'description': 'Analyst relations at Akamai, mother of two, live in Munich. Views are my own.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 293,
#    'friends_count': 430,
#    'listed_count': 47,
#    'created_at': 'Fri Jun 05 09:36:27 +0000 2009',
#    'favourites_count': 1230,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 1539,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/2902585173/ad614eb917740decc3c10b0d91b13827_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2902585173/ad614eb917740decc3c10b0d91b13827_normal.jpeg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/44858298/1509703870',
#    'profile_link_color': 'FF691F',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Thu May 28 08:05:13 +0000 2020',
#   'id': 1265917028818472960,
#   'id_str': '1265917028818472960',
#   'text': 'State-of-the-art #IP &amp; #IT-based solutions for #ATC #communications, in-house #cybersecurity expertise &amp; new #ATC d… https://t.co/f7K49P5A0F',
#   'truncated': True,
#   'entities': {'hashtags': [{'text': 'IP', 'indices': [17, 20]},
#     {'text': 'IT', 'indices': [27, 30]},
#     {'text': 'ATC', 'indices': [51, 55]},
#     {'text': 'communications', 'indices': [56, 71]},
#     {'text': 'cybersecurity', 'indices': [82, 96]},
#     {'text': 'ATC', 'indices': [117, 121]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/f7K49P5A0F',
#      'expanded_url': 'https://twitter.com/i/web/status/1265917028818472960',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [125, 148]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1201894951396823040,
#    'id_str': '1201894951396823040',
#    'name': 'RohdeSchwarzATC',
#    'screen_name': 'AtcRohde',
#    'location': 'Munich',
#    'description': 'A renowned world-leading provider of end to end communications solutions, from the microphone to the antenna, for Air Traffic Control (ATC).',
#    'url': 'https://t.co/J5YDOan9A3',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/J5YDOan9A3',
#        'expanded_url': 'https://www.rohde-schwarz.com/atc',
#        'display_url': 'rohde-schwarz.com/atc',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 70,
#    'friends_count': 155,
#    'listed_count': 2,
#    'created_at': 'Tue Dec 03 16:06:26 +0000 2019',
#    'favourites_count': 544,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 471,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1201895515782352896/igbB0l_5_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1201895515782352896/igbB0l_5_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1201894951396823040/1575389371',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'}]
